# %% [markdown]
# ## 1. Stochastic Model
# - Langevin dynamics
# - White noise assumptions
#
# ## 2. Numerical Integration

# %%
from src.sde_noise import simulate_noise, compute_psd
I = simulate_noise(tau=1e-3, dt=1e-6)
f, psd = compute_psd(I)

# %% [markdown]
# ## 3. Spectral Validation
# - Lorentzian fit
# - Bandwidth dependence on τ
#
# ## 4. Numerical Artifacts
# - Finite time window
# - FFT leakage
