# %% [markdown]
# ## 1. Physical Model & Assumptions
# - Electrostatic approximation
# - Piecewise constant permittivity
# - Charge neutrality regions
#
# ## 2. Numerical Discretization
# - Finite difference stencil
# - Sparse matrix formulation
#
# ## 3. Solver Implementation

# %%
from src.poisson_solver import solve_poisson
phi, Ex, Ey = solve_poisson(Nx=100, Ny=60)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.13.7' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 4. Convergence Study
# - Grid refinement
# - Residual norms
#
# ## 5. Interpretation
# - Physical consistency
# - Limitations
